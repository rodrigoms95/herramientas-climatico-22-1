# %%
# Genera varios mapas
# para el paper.

import pandas as pd
import numpy as np

import holoviews as hv
import geoviews as gv
import geopandas as gpd

from cartopy import crs

from matplotlib import pyplot as plt
from cartopy import feature as cf
from geoviews import feature as gf

from geoviews.element import Feature

# Se carga el motor gráfico de Geoviews.
gv.extension("matplotlib")
hv.output(backend = "matplotlib", size = 300)
# Out:
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
# Escenarios.
RCP = ["RCP8p5"]
fut = [2030]
#RCP = ["RCP4p5", "RCP8p5"]
#fut = [2030, 2050, 2070]
esc = ["Actual"] + fut

# Directorios.
csv = "_Pago.csv"
perc = "_perc.csv"
dirs = ["Actual"] + RCP
path = "../../../resultados/"
path_data = [path + "data/" + x + "/data" for x in dirs]
path_files = ( [path_data[0] + csv] +
    [path_data[1] + "." + str(x) + csv for x in fut]
    + [path_data[1] + "_10." + str(x) + perc for x in fut]
    + [path_data[1] + "_11." + str(x) + perc for x in fut] )

path_d = "../../../datos/"
path_shp = path_d + "Municipios/Mapas/mun20gw.shp"

# Cargamos los municipios.
gdf = gpd.read_file( path_shp )

# Renombramos la columna que identifica cada 
# municipio con el valor único de INEGI.
gdf.rename(columns = {
    "CVEGEO": "CVE_INEGI"},
    inplace = True)

gdf.set_index(gdf["CVE_INEGI"].astype(int), inplace = True)

df = []

for i  in path_files: 
    df.append(pd.read_csv(i, index_col = "CVE_INEGI"))

#grid = Feature(cf.NaturalEarthFeature(
#    category = "physical", name = "graticules_5",
#    scale = "110m"), group = "Grid")
#border = Feature(cf.NaturalEarthFeature(
#    category = "physical", name = "borders",
#    scale = "10m"), group = "Borders")
#coastline = Feature(cf.NaturalEarthFeature(
#    category = "physical", name = "coastline",
#    scale = "10m"), group = "Coastline")

# %%
var = ["Tmean", "Mean temperature increase [°C]"]

gdf[var[1]] = df[1][var[0]] - df[0][var[0]]

opts = { "colorbar": True,
#    "projection": crs.LambertConformal(),
#    "line_width": 0,
#    "width": 600,
    "linewidth": 0,
    "cmap": "Reds"
    }

map = ( gv.Polygons(gdf, vdims = var[1]).opts(**opts)
    * gf.coastline * gf.borders #* grid
    )

map
# Out:
# :Overlay
#    .Polygons.I  :Polygons   [Longitude,Latitude]   (Mean temperature increase [°C])
#    .Coastline.I :Feature   [Longitude,Latitude]
#    .Borders.I   :Feature   [Longitude,Latitude]

# %%
var = ["Pre", "Precipitation change [%]"]

gdf[var[1]] = ( df[1][var[0]] / df[0][var[0]] - 1 ) * 100

opts = { "colorbar": True,
    #"projection": crs.LambertConformal(),
    #"line_width": 0,
    #"width": 600,
    "linewidth": 0,
    "cmap": "BrBG"
    }

map = ( gv.Polygons( gdf,
    vdims = hv.Dimension( var[1], range = (
        -np.abs(gdf[var[1]]).max(),
        +np.abs(gdf[var[1]]).max() ) )
    ).opts(**opts) * gf.coastline * gf.borders #* grid
    )

map
# Out:
# :Overlay
#    .Polygons.I  :Polygons   [Longitude,Latitude]   (Precipitation change [%])
#    .Coastline.I :Feature   [Longitude,Latitude]
#    .Borders.I   :Feature   [Longitude,Latitude]

# %%
var = ["Poblacion", "Population change [%]"]

gdf[var[1]] = ( df[2][var[0]] - 1 ) * 100

opts = { "colorbar": True,
    #"projection": crs.LambertConformal(),
    #"line_width": 0,
    #"width": 600,
    "linewidth": 0,
    "cmap": "PRGn"
    }

map = ( gv.Polygons( gdf,
    vdims = hv.Dimension( var[1], range = (
        -np.abs(gdf[var[1]]).max(),
        +np.abs(gdf[var[1]]).max() ) )
    ).opts(**opts) * gf.coastline * gf.borders #* grid
    )

map
# Out:
# :Overlay
#    .Polygons.I  :Polygons   [Longitude,Latitude]   (Population change [%])
#    .Coastline.I :Feature   [Longitude,Latitude]
#    .Borders.I   :Feature   [Longitude,Latitude]

# %%
var = ["PIB", "GPD change [%]"]

gdf[var[1]] = ( df[3][var[0]] - 1 ) * 100

opts = { "colorbar": True,
    #"projection": crs.LambertConformal(),
    #"line_width": 0,
    #"width": 600,
    "linewidth": 0,
    "cmap": "YlOrBr",
    }

map = ( gv.Polygons(gdf, vdims = var[1]).opts(**opts)
    * gf.coastline * gf.borders #* grid
    )

map
# Out:
# :Overlay
#    .Polygons.I  :Polygons   [Longitude,Latitude]   (GPD change [%])
#    .Coastline.I :Feature   [Longitude,Latitude]
#    .Borders.I   :Feature   [Longitude,Latitude]

# %%
var = ["Tarifa", "Tariff type"]

gdf[var[1]] = df[0][var[0]].where(
    df[0][var[0]] != "DAC", "1F" )

opts = { "colorbar": True,
    #"projection": crs.LambertConformal(),
    #"line_width": 0,
    #"width": 600,
    "linewidth": 0,
    "cmap": "Spectral_r",
    "cbar_ticks": [ (0.43, "1"), (1.29, "1A"),
        (2.14, "1B"), (3, "1C"), (3.86, "1D"),
        (4.71, "1E"), (5.57, "1F"), ] 
    }

map = ( gv.Polygons(gdf, vdims = var[1]).opts(**opts)
    * gf.coastline * gf.borders #* grid
    )

map
# Out:
# :Overlay
#    .Polygons.I  :Polygons   [Longitude,Latitude]   (Tariff type)
#    .Coastline.I :Feature   [Longitude,Latitude]
#    .Borders.I   :Feature   [Longitude,Latitude]

# %%
var = ["Tarifa", "Tariff type"]

gdf[var[1]] = df[1][var[0]].where(
    df[1][var[0]] != "DAC", "1F" )

opts = { "colorbar": True,
    #"projection": crs.LambertConformal(),
    #"line_width": 0,
    #"width": 600,
    "linewidth": 0,
    "cmap": "Spectral_r",
    "cbar_ticks": [ (0.43, "1"), (1.29, "1A"),
        (2.14, "1B"), (3, "1C"), (3.86, "1D"),
        (4.71, "1E"), (5.57, "1F"), ] 
    }

map = ( gv.Polygons(gdf, vdims = var[1]).opts(**opts)
    * gf.coastline * gf.borders #* grid
    )

map
# Out:
# :Overlay
#    .Polygons.I  :Polygons   [Longitude,Latitude]   (Tariff type)
#    .Coastline.I :Feature   [Longitude,Latitude]
#    .Borders.I   :Feature   [Longitude,Latitude]

# %%
def tar(x):
    if   x == "1" : y = 0
    elif x == "1A": y = 1
    elif x == "1B": y = 2
    elif x == "1C": y = 3
    elif x == "1D": y = 4
    elif x == "1E": y = 5
    elif x == "1F": y = 6
    else          : y = 6
    return y

var = ["Tarifa", "Tariff change"]

gdf[var[1]] = ( df[1][var[0]].apply(tar)
    - df[0][var[0]].apply(tar) )

opts = { "colorbar": True,
    #"projection": crs.LambertConformal(),
    #"line_width": 0,
    #"width": 600,
    "linewidth": 0,
    "cmap": "plasma"
    }

map = ( gv.Polygons(gdf, vdims = var[1]).opts(**opts)
    * gf.coastline * gf.borders #* grid
    )

map
# Out:
# :Overlay
#    .Polygons.I  :Polygons   [Longitude,Latitude]   (Tariff type)
#    .Coastline.I :Feature   [Longitude,Latitude]
#    .Borders.I   :Feature   [Longitude,Latitude]
